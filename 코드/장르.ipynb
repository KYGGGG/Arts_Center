# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/2023빅콘
# Out:
# /content/drive/MyDrive/Colab Notebooks/2023빅콘

# %%
import pandas as pd
import numpy as np
pd.set_option('mode.chained_assignment',  None) # 복사 경고 무시

# %%
# 데이터 불러오기
data = pd.read_csv('2023빅콘테스트_어드밴스드리그_예술의전당.csv', encoding = 'UTF8')
df = pd.DataFrame(data)

# %%
df[df['genre'].isna()]
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 107       NaN    NaN               NaN               NaN               NaN
# 138      40.0      M                블루                골드                무료
# 383      30.0      F                무료                그린               NaN
# 440      30.0      F                무료               NaN               NaN
# 617      60.0      M                골드                무료               NaN
# ...       ...    ...               ...               ...               ...
# 1920514   NaN    NaN               NaN               NaN               NaN
# 1920648  30.0      M                무료               NaN               NaN
# 1920735   NaN    NaN               NaN               NaN               NaN
# 1920745   NaN    NaN               NaN               NaN               NaN
# 1920760   NaN    NaN               NaN               NaN               NaN
#
#         membership_type_4 membership_type_5  membership_type_6  tran_date  \
# 107                   NaN               NaN                NaN   20221112
# 138                   NaN               NaN                NaN   20230415
# 383                   NaN               NaN                NaN   20230212
# 440                   NaN               NaN                NaN   20220131
# 617                   NaN               NaN                NaN   20230212
# ...                   ...               ...                ...        ...
# 1920514               NaN               NaN                NaN   20230416
# 1920648               NaN               NaN                NaN   20230511
# 1920735               NaN               NaN                NaN   20230305
# 1920745               NaN               NaN                NaN   20221112
# 1920760               NaN               NaN                NaN   20230416
#
#          tran_time  ...  ticket_cancel  discount_type performance_code  \
# 107           1204  ...              0            초대권              229
# 138           1406  ...              0     골드회원 할인20%             2818
# 383           1402  ...              0     그린회원 할인15%              352
# 440           1435  ...              0             일반             1221
# 617           1407  ...              2     골드회원 할인20%              352
# ...            ...  ...            ...            ...              ...
# 1920514       2330  ...              0           한화생명             2818
# 1920648        955  ...              0             일반             2818
# 1920735       1516  ...              0           한화생명             2816
# 1920745       1229  ...              0            초대권              229
# 1920760       2335  ...              0           한화생명             2818
#
#          pre_open_date   open_date genre  place  running_time  intermission  \
# 107         20221017.0  20221018.0   NaN   콘서트홀           110            20
# 138         20230415.0  20230416.0   NaN   콘서트홀           120            15
# 383         20230212.0  20230213.0   NaN   콘서트홀           120            20
# 440         20220211.0  20220212.0   NaN   콘서트홀           110            20
# 617         20230212.0  20230213.0   NaN   콘서트홀           120            20
# ...                ...         ...   ...    ...           ...           ...
# 1920514     20230415.0  20230416.0   NaN   콘서트홀           120            15
# 1920648     20230415.0  20230416.0   NaN   콘서트홀           120            15
# 1920735     20230211.0  20230212.0   NaN   콘서트홀           120            15
# 1920745     20221017.0  20221018.0   NaN   콘서트홀           110            20
# 1920760     20230415.0  20230416.0   NaN   콘서트홀           120            15
#
#         member_yn
# 107             N
# 138             Y
# 383             Y
# 440             Y
# 617             Y
# ...           ...
# 1920514         N
# 1920648         Y
# 1920735         N
# 1920745         N
# 1920760         N
#
# [25842 rows x 24 columns]
